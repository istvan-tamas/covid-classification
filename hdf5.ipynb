# %%
import h5py

# %%
f = h5py.File('mytestfile.hdf5','w')

# %%
f.name
# Out:
# '/'

# %%
list(f.keys())
# Out:
# []

# %%
grp = f.create_group("bar")

# %%
grp.name
# Out:
# '/bar'

# %%
f.name
# Out:
# '/'

# %%
subgrp = grp.create_group("baz")

# %%
subgrp.name
# Out:
# '/bar/baz'

# %%
grp2 = f.create_group("/some/long/path")

# %%
grp2.name
# Out:
# '/some/long/path'

# %%
f['/bar/baz/']
# Out:
# <HDF5 group "/bar/baz" (0 members)>

# %%
subgrp
# Out:
# <HDF5 group "/bar/baz" (0 members)>

# %%
f.close()
