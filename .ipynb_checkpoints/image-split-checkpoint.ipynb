# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_to_split = pd.read_csv('train_val_metadata.csv')

# %%
number_of_folds = 5
folds = []

# %%
len(data_to_split)
# Out:
# 5565

# %%
data_to_split.columns.values.tolist()
# Out:
# ['patient id',
#  'source',
#  'country',
#  'sex',
#  'age',
#  'finding',
#  'verified finding',
#  'slice selection',
#  'view',
#  'modality']

# %%
# findig the images for the patients

# %%
patient_images = pd.read_csv('txt/train_val_COVIDx_CT-3A.csv', sep=' ',header=0)
full_set = pd.DataFrame(columns=data_to_split.columns.values.tolist())
full_set = data_to_split
full_set['images'] = ' '

# %%
for i, row in full_set.iterrows():
    mask = patient_images['fname'].str.match(pat='{}[^A-Za-z0-9]'.format(row['patient id']))
    images = np.array(patient_images[mask])
    full_set.at[i,'images'] = images

# %%
full_set.iloc[0]['images']
# Out:
# array([['CP_10_3153_0172.png', 1, 30, 93, 474, 419],
#        ['CP_10_3153_0175.png', 1, 32, 94, 473, 419],
#        ['CP_10_3153_0182.png', 1, 34, 99, 471, 418],
#        ['CP_10_3153_0183.png', 1, 35, 99, 470, 418],
#        ['CP_10_3153_0191.png', 1, 38, 102, 467, 418]], dtype=object)

# %%
already_sampled = pd.DataFrame(columns=full_set.columns.values.tolist())

for i in range(0,number_of_folds):
    
    training_set = pd.DataFrame(columns=full_set.columns.values.tolist())
    val_set = pd.DataFrame(columns=full_set.columns.values.tolist())
    
    training_set = full_set

    i = 0
    
    while(i < int(len(data_to_split)/number_of_folds)):
        sample = training_set.sample(n=1)
        if sample['patient id'].isin(already_sampled['patient id']).values[0]:
            continue
        else:
            val_set = pd.concat([val_set,sample])
            already_sampled = pd.concat([already_sampled,sample])
            training_set = training_set.drop(sample.index, inplace=False)
            i = i + 1

    
    temp = []
    temp.append(training_set)
    temp.append(val_set)
    folds.append(temp)

# %%
folds[0][0]
# Out:
#                patient id       source country  sex   age    finding  \
# 0                   CP_10         CNCB   China  NaN   NaN  Pneumonia
# 2                 CP_1071         CNCB   China  NaN   NaN  Pneumonia
# 3                 CP_1072         CNCB   China  NaN   NaN  Pneumonia
# 4                 CP_1073         CNCB   China  NaN   NaN  Pneumonia
# 6                 CP_1076         CNCB   China  NaN   NaN  Pneumonia
# ...                   ...          ...     ...  ...   ...        ...
# 5560  COVIDCTMD-normal071  COVID-CT-MD    Iran    F  43.0     Normal
# 5561  COVIDCTMD-normal072  COVID-CT-MD    Iran    M  31.0     Normal
# 5562  COVIDCTMD-normal073  COVID-CT-MD    Iran    M  39.0     Normal
# 5563  COVIDCTMD-normal074  COVID-CT-MD    Iran    M  40.0     Normal
# 5564  COVIDCTMD-normal076  COVID-CT-MD    Iran    M  30.0     Normal
#
#      verified finding slice selection   view modality  \
# 0                 Yes       Automatic  Axial       CT
# 2                 Yes          Expert  Axial       CT
# 3                 Yes          Expert  Axial       CT
# 4                 Yes          Expert  Axial       CT
# 6                 Yes          Expert  Axial       CT
# ...               ...             ...    ...      ...
# 5560              Yes             NaN  Axial       CT
# 5561              Yes             NaN  Axial       CT
# 5562              Yes             NaN  Axial       CT
# 5563              Yes             NaN  Axial       CT
# 5564              Yes             NaN  Axial       CT
#
#                                                  images
# 0     [[CP_10_3153_0172.png, 1, 30, 93, 474, 419], [...
# 2     [[CP_1071_3114_0035.png, 1, 33, 117, 501, 451]...
# 3     [[CP_1072_3115_0037.png, 1, 46, 73, 472, 385],...
# 4     [[CP_1073_3116_0031.png, 1, 22, 71, 503, 389],...
# 6     [[CP_1076_3120_0045.png, 1, 57, 84, 468, 396],...
# ...                                                 ...
# 5560  [[COVIDCTMD-normal071-IM0001.png, 0, 0, 97, 51...
# 5561  [[COVIDCTMD-normal072-IM0001.png, 0, 0, 139, 5...
# 5562  [[COVIDCTMD-normal073-IM0001.png, 0, 0, 111, 5...
# 5563  [[COVIDCTMD-normal074-IM0001.png, 0, 0, 126, 5...
# 5564  [[COVIDCTMD-normal076-IM0001.png, 0, 0, 114, 5...
#
# [4452 rows x 11 columns]

# %%
len(already_sampled)
# Out:
# 5565

# %%
for i in range(0, len(folds)):
    print("Training set length: " + str(len(folds[i][0])))
    print("Validation set length: " + str(len(folds[i][1])))
    print("Total dataset length: " + str(len(folds[i][0]) + len(folds[i][1])))
    print("\n")
# Out:
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565

# %%
# Distribution of class labels in training data
for i in range(0, len(folds)):
    print(folds[i][0]['finding'].value_counts(normalize=True))
# Out:
# finding
# COVID-19     0.769991
# Pneumonia    0.142857
# Normal       0.087152
# Name: proportion, dtype: float64
# finding
# COVID-19     0.768868
# Pneumonia    0.144205
# Normal       0.086927
# Name: proportion, dtype: float64
# finding
# COVID-19     0.772013
# Pneumonia    0.140836
# Normal       0.087152
# Name: proportion, dtype: float64
# finding
# COVID-19     0.772013
# Pneumonia    0.141959
# Normal       0.086029
# Name: proportion, dtype: float64
# finding
# COVID-19     0.767969
# Pneumonia    0.143531
# Normal       0.088500
# Name: proportion, dtype: float64

# %%
# Distribution of class labels in validation data
for i in range(0, len(folds)):
    print(folds[i][1]['finding'].value_counts(normalize=True))
# Out:
# finding
# COVID-19     0.770889
# Pneumonia    0.141959
# Normal       0.087152
# Name: proportion, dtype: float64
# finding
# COVID-19     0.775382
# Pneumonia    0.136568
# Normal       0.088050
# Name: proportion, dtype: float64
# finding
# COVID-19     0.762803
# Pneumonia    0.150045
# Normal       0.087152
# Name: proportion, dtype: float64
# finding
# COVID-19     0.762803
# Pneumonia    0.145553
# Normal       0.091644
# Name: proportion, dtype: float64
# finding
# COVID-19     0.778976
# Pneumonia    0.139263
# Normal       0.081761
# Name: proportion, dtype: float64

# %%
for i in range(0, len(folds)):
    print(folds[0][1]['patient id'].reset_index(drop=True) == folds[i][1]['patient id'].reset_index(drop=True))
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1108    True
# 1109    True
# 1110    True
# 1111    True
# 1112    True
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=number_of_folds, shuffle=True, random_state=11)

# %%
folds = []

# %%
for i, (train_index, val_index) in enumerate(kf.split(full_set)):
    split = []
    split.append(full_set.iloc[train_index])
    split.append(full_set.iloc[val_index])
    folds.append(split)

# %%
for i in range(0, len(folds)):
    print("Training set length: " + str(len(folds[i][0])))
    print("Validation set length: " + str(len(folds[i][1])))
    print("Total dataset length: " + str(len(folds[i][0]) + len(folds[i][1])))
    print("\n")
# Out:
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565
#
#
# Training set length: 4452
# Validation set length: 1113
# Total dataset length: 5565

# %%
# Distribution of class labels in training data
for i in range(0, len(folds)):
    print(folds[i][0]['finding'].value_counts(normalize=True))
# Out:
# finding
# COVID-19     0.772237
# Pneumonia    0.140836
# Normal       0.086927
# Name: proportion, dtype: float64
# finding
# COVID-19     0.772013
# Pneumonia    0.140162
# Normal       0.087826
# Name: proportion, dtype: float64
# finding
# COVID-19     0.766622
# Pneumonia    0.148248
# Normal       0.085130
# Name: proportion, dtype: float64
# finding
# COVID-19     0.769766
# Pneumonia    0.142183
# Normal       0.088050
# Name: proportion, dtype: float64
# finding
# COVID-19     0.770216
# Pneumonia    0.141959
# Normal       0.087826
# Name: proportion, dtype: float64

# %%
# Distribution of class labels in validation data
for i in range(0, len(folds)):
    print(folds[i][1]['finding'].value_counts(normalize=True))
# Out:
# finding
# COVID-19     0.761905
# Pneumonia    0.150045
# Normal       0.088050
# Name: proportion, dtype: float64
# finding
# COVID-19     0.762803
# Pneumonia    0.152740
# Normal       0.084456
# Name: proportion, dtype: float64
# finding
# COVID-19     0.784367
# Pneumonia    0.120395
# Normal       0.095238
# Name: proportion, dtype: float64
# finding
# COVID-19     0.771788
# Pneumonia    0.144654
# Normal       0.083558
# Name: proportion, dtype: float64
# finding
# COVID-19     0.769991
# Pneumonia    0.145553
# Normal       0.084456
# Name: proportion, dtype: float64

# %%
from pandas.testing import assert_frame_equal

# %%
for i in range(0, len(folds)):
    print(folds[0][1]['patient id'].reset_index(drop=True) == folds[i][1]['patient id'].reset_index(drop=True))
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1108    True
# 1109    True
# 1110    True
# 1111    True
# 1112    True
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1108    False
# 1109    False
# 1110    False
# 1111    False
# 1112    False
# Name: patient id, Length: 1113, dtype: bool

# %%
folds[0][0]
# Out:
#                patient id       source country  sex   age    finding  \
# 0                   CP_10         CNCB   China  NaN   NaN  Pneumonia
# 2                 CP_1071         CNCB   China  NaN   NaN  Pneumonia
# 3                 CP_1072         CNCB   China  NaN   NaN  Pneumonia
# 4                 CP_1073         CNCB   China  NaN   NaN  Pneumonia
# 6                 CP_1076         CNCB   China  NaN   NaN  Pneumonia
# ...                   ...          ...     ...  ...   ...        ...
# 5560  COVIDCTMD-normal071  COVID-CT-MD    Iran    F  43.0     Normal
# 5561  COVIDCTMD-normal072  COVID-CT-MD    Iran    M  31.0     Normal
# 5562  COVIDCTMD-normal073  COVID-CT-MD    Iran    M  39.0     Normal
# 5563  COVIDCTMD-normal074  COVID-CT-MD    Iran    M  40.0     Normal
# 5564  COVIDCTMD-normal076  COVID-CT-MD    Iran    M  30.0     Normal
#
#      verified finding slice selection   view modality  \
# 0                 Yes       Automatic  Axial       CT
# 2                 Yes          Expert  Axial       CT
# 3                 Yes          Expert  Axial       CT
# 4                 Yes          Expert  Axial       CT
# 6                 Yes          Expert  Axial       CT
# ...               ...             ...    ...      ...
# 5560              Yes             NaN  Axial       CT
# 5561              Yes             NaN  Axial       CT
# 5562              Yes             NaN  Axial       CT
# 5563              Yes             NaN  Axial       CT
# 5564              Yes             NaN  Axial       CT
#
#                                                  images
# 0     [[CP_10_3153_0172.png, 1, 30, 93, 474, 419], [...
# 2     [[CP_1071_3114_0035.png, 1, 33, 117, 501, 451]...
# 3     [[CP_1072_3115_0037.png, 1, 46, 73, 472, 385],...
# 4     [[CP_1073_3116_0031.png, 1, 22, 71, 503, 389],...
# 6     [[CP_1076_3120_0045.png, 1, 57, 84, 468, 396],...
# ...                                                 ...
# 5560  [[COVIDCTMD-normal071-IM0001.png, 0, 0, 97, 51...
# 5561  [[COVIDCTMD-normal072-IM0001.png, 0, 0, 139, 5...
# 5562  [[COVIDCTMD-normal073-IM0001.png, 0, 0, 111, 5...
# 5563  [[COVIDCTMD-normal074-IM0001.png, 0, 0, 126, 5...
# 5564  [[COVIDCTMD-normal076-IM0001.png, 0, 0, 114, 5...
#
# [4452 rows x 11 columns]
